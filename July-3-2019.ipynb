# %%
import pandas as pd
def readAPPCSVdatadescription(filepath):
    return pd.read_csv(filepath)

filepath = "DataFiles/appleStore_description.csv"
readAPPCSVdatadescription(filepath)
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
import pandas as pd
def readAPPCSVdata(filepath):
    return pd.read_csv(filepath)

filepath = "DataFiles/AppleStore.csv"
readAPPCSVdata(filepath)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
appdata = readAPPCSVdata(filepath)

# %%
# list of all unique Track_name

list(appdata['track_name'])
# Out:
# ['PAC-MAN Premium',
#  'Evernote - stay organized',
#  'WeatherBug - Local Weather, Radar, Maps, Alerts',
#  'eBay: Best App to Buy, Sell, Save! Online Shopping',
#  'Bible',
#  'Shanghai Mahjong',
#  'PayPal - Send and request money safely',
#  'Pandora - Music & Radio',
#  'PCalc - The Best Calculator',
#  'Ms. PAC-MAN',
#  'Solitaire by MobilityWare',
#  'SCRABBLE Premium',
#  'Google – Search made just for mobile',
#  'Bank of America - Mobile Banking',
#  'FreeCell',
#  'TripAdvisor Hotels Flights Restaurants',
#  'Facebook',
#  'Yelp - Nearby Restaurants, Shopping & Services',
#  'Shazam - Discover music, artists, videos & lyrics',
#  'Crash Bandicoot Nitro Kart 3D',
#  'iQuran',
#  ':) Sudoku +',
#  'Yahoo Sports - Teams, Scores, News & Highlights',
#  'Mileage Log | Fahrtenbuch',
#  'Cleartune - Chromatic Tuner',
#  'Lifesum – Inspiring healthy lifestyle app',
#  'Hangman.',
#  'iTranslate - Language Translator & Dictionary',
#  'TouchOSC',
#  'RadarScope',
#  'LinkedIn',
# ...

# %%
# List of all unique Prime_Genres (categories) in the data set


list(appdata['prime_genre'].unique())
# Out:
# ['Games',
#  'Productivity',
#  'Weather',
#  'Shopping',
#  'Reference',
#  'Finance',
#  'Music',
#  'Utilities',
#  'Travel',
#  'Social Networking',
#  'Sports',
#  'Business',
#  'Health & Fitness',
#  'Entertainment',
#  'Photo & Video',
#  'Navigation',
#  'Education',
#  'Lifestyle',
#  'Food & Drink',
#  'News',
#  'Book',
#  'Medical',
#  'Catalogs']

# %%
appdata
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
# Category with highest number of apps

#appdata.groupby('prime_genre').count().idxmax()

appdata.drop_duplicates().prime_genre.value_counts().idxmax()
# Out:
# 'Games'

# %%
# Category with lowest number of apps

appdata.drop_duplicates().prime_genre.value_counts().idxmin()
# Out:
# 'Catalogs'

# %%
# Category with highest user rating
appdata.index = appdata['prime_genre']
appdata[appdata['user_rating'] == 5.0].index.unique()
# Out:
# Index(['Games', 'Business', 'Education', 'Photo & Video', 'Utilities',
#        'Shopping', 'News', 'Health & Fitness', 'Productivity', 'Food & Drink',
#        'Reference', 'Travel', 'Lifestyle', 'Weather', 'Music', 'Book',
#        'Finance', 'Sports', 'Entertainment', 'Social Networking', 'Catalogs',
#        'Medical', 'Navigation'],
#       dtype='object', name='prime_genre')

# %%
# App with highest downloads

# %%
# Average user rating for free apps

appdata = readAPPCSVdata(filepath)
#count_free = appdata[appdata['price'] == 0].count().unique()[0]
appdata[appdata['price'] == 0]['user_rating'].mean()
# Out:
# 3.3767258382642997

# %%
# Average user rating for paid apps

appdata[appdata['price'] > 0]['user_rating'].mean()
# Out:
# 3.720948742438714

# %%
m = [1,2,3,4,6]

# %%
0-0
# Out:
# 0

# %%
n,m,g = map(int, input().split())
rain = list(map(int, input().split()))
dry = list(map(int, input().split()))
# Out:
# 3 3 2
# 3 5 8
# 4 1 3

# %%
count = 0
difference = rain[1]-rain[0]
difference
# Out:
# 2

# %%
diff = 0
j = 0
while j < n-1:
    new_diff = time[j+1] - time[j]
    if (new_diff > diff):
        diff = new_diff
    j += 1
possibilities = [x for x in values if x <= diff]
print(len(possibilities))

# %%
n = int(input())
a = list(map(int, input().split()))
m = int(input())
c = list(map(int, input().split()))
repeat_b=[]
count = 1
b=[]
if n < m:
    for i in range(m):
        for j in a:
            repeat_b.append(c[i]-j)
#print(repeat_b)
for i in repeat_b:
    if repeat_b.count(i)>1:
        b.append(i)
print(" ".join(list(map(str,set(b)))))
# Out:
# 4
# 4 2 3 1
# 7
# 2 3 4 5 6 7 8
# 0 1 2 3 4 5 6 -1
