# %% [markdown]
# -- That second sum answer

# %%
def uniquelist(allno):
    unique=[]
    for n in allno:
        if n not in unique:
            unique.append(n)
    return unique
    
def numberlist(s):
    allno=[]
    for i in s:
        if i.isdigit():
            allno.append(i)
    return allno
s=input()
numberlist(s)
uniquelist(a)
# Out:
# sdfaesa12344dfgreg13996
# ['1', '2', '3', '4', '9', '6']

# %%
string=input()
for digit in range(0,10):
    print(string.count(str(digit)),end="")
# Out:
# s;dorgd1234ejqrgn413526452
# 0232321000

# %%
#my solution that i understood:
def digitFrquency(s):
    a=numberlist(s)
    b=uniquelist(a)
    for i in range(0,10):
        if str(i) not in b:
            print(0,end=' ')
        else:
            count=a.count(str(i))
            print(count,end=' ')
s=input()
digitFrquency(s)
# Out:
# sdfaesa12344dfgreg13996
# 0 2 1 2 2 0 1 0 0 2

# %%
# all file concepts for gr=enrating data into files breating average of marks and etc';;
# for generating random data into a file
#Function to generate marks data for n students
from random import randint
def generateMarks(n,lb,ub):
    with open('DataFiles/randomMarks.txt','w') as f:
        for i in range(0,n):
            r=randint(lb,ub)
            f.write(str(r)+'\n')
    return
 
generateMarks(100,1,75)

# %%
filename='Datafiles/randomMarks.txt'

# %%
#read data from file and store in a list
def markslist(filename):
    l=[]
    with open(filename,'r') as f: #opening file and reading data and storing it into a varible s
        s=f.read() #Reading Data from the file
        d=s.split('\n') #data spliting into list with removing \n(new line)
        for i in d:
            l.append(int(i)) # we want interger data so we are converting it into that
        return l

# %%
#class Average
def classAverage(filename):
    m=markslist(filename)
    cA=sum(m)/len(m)
    return cA

# %%
print(classAverage('Datafiles/randomMarks.txt'))
# Out:
# 42.19

# %%
# print class 1st mark
def firstMark(filename):
    first=markslist(filename)
    return max(first)
print(firstMark(filename))
# Out:
# 75

# %%
# pass percentage of students:
def passPercentage(filename):
    m=markslist(filename)
    noofpassed=[]
    for i in m:
        if i>40:
            noofpassed.append(i)
    passpercent=(len(noofpassed)/len(m))*100
    return passpercent

# %%
passPercentage(filename)
# Out:
# 54.0

# %%
#fail percentage
def failPercentage(filename):
    m=markslist(filename)
    nooffailed=[]
    for i in m:
        if i<40:
            nooffailed.append(i)
    failpercent=((len( nooffailed)/len(m))*100)
    return failpercent

# %%
failPercentage(filename)
# Out:
# 44.0

# %%
#frequency of passed fellows
def frequencyOfPassed(filename):
    m=markslist(filename)
    pl=[]
    for i in m:
        if i>40:
            pl.append(i)
    return pl



s=frequencyOfPassed(filename) 
print(s)
print(len(s))
# Out:
# [65, 58, 47, 45, 63, 70, 67, 50, 63, 49, 68, 64, 52, 71, 74, 61, 53, 65, 75, 60, 71, 62, 48, 58, 61, 70, 42, 41, 43, 67, 63, 65, 65, 60, 65, 67, 43, 64, 72, 41, 73, 56, 74, 50, 62, 54, 42, 71, 55, 52, 71, 47, 66, 72]
# 54

# %%
#frequency of failed fellows
def frequencyOfFailed(filename):
    m=markslist(filename)
    fL=[]
    for i in m:
        if i<40:
            fL.append(i)
    return fL

p=frequencyOfFailed(filename)
print(p,len(p))
# Out:
# [27, 7, 29, 19, 11, 35, 2, 23, 4, 9, 4, 1, 35, 32, 37, 24, 9, 31, 26, 2, 35, 26, 24, 16, 23, 30, 24, 28, 26, 19, 37, 20, 21, 39, 16, 12, 11, 26, 24, 5, 13, 29, 5, 30] 44

# %%
#Anagrams:
#function to check if two strings are anagrams
#aabbcc ccbbaaa   -->False
#abc cab --->True
def checkAnagrams(s1,s2):
    if len(s1) != len(s2):
        return False
    if sorted(s1)==sorted(s2):
        return True
    return False

checkAnagrams('abc','abc')
# Out:
# True

# %%
def charDeletionsAnagrams(s1,s2):
    uncommon=[] #collect all uncommon characters in s1 and s2 which give us no deltions as a count
    for i in s1:
        if i not in s2:
            uncommon.append(i)
    for i in s2:
        if i not in s1:
            uncommon.append(i)
    count=len(uncommon)
    freqs1={} #frequency of s1 represents frequency of common characters in s1
    freqs2={} #frquency of characters of s2
    uniqs1=[] #unique characters in s1
    uniqs2=[] #unique characters in s2
    for i in s1:
        if i not in uncommon and i not in uniqs1:
            freqs1[i]=s1.count(i)
            uniqs1.append(i)
    for i in s2:
        if i not in uncommon and i not in uniqs2:
            freqs2[i]=s2.count(i)
            uniqs2.append(i)
    for key in freqs1.keys():
        count+=abs(freqs1[key]-freqs2[key])
    return count

charDeletionsAnagrams("cde","abc")
# Out:
# 4

# %%
#full solution for anangarm
def charDeletionsAnagrams(s1,s2):
    uncommon=[]
    for i in s1:
        if i not in s2:
            uncommon.append(i)
    for i in s2:
        if i not in s1:
            uncommon.append(i)
    count=len(uncommon)
    freqs1={}
    freqs2={}
    uniqs1=[]
    uniqs2=[]
    for i in s1:
        if i not in uncommon and i not in uniqs1:
            freqs1[i]=s1.count(i)
            uniqs1.append(i)
    for i in s2:
        if i not in uncommon and i not in uniqs2:
            freqs2[i]=s2.count(i)
            uniqs2.append(i)
    for key in freqs1.keys():
        count+=abs(freqs1[key]-freqs2[key])
    return count



            
n=int(input())
for i in range(0,n):
    s1=input()
    s2=input()
    print(charDeletionsAnagrams(s1,s2))

# %%
#That average sum problem sum very easy problemmmmm
def averageRange(lb,ub):
    sum=0
    for i in range(lb,ub+1):
        sum+=i
    count=ub-lb+1
    avg=sum//count
    return avg

averageRange(1000,123456)
# Out:
# 62228

# %%
#that easy problemmmmmmmmmmmm
def kLargestFrequency(s,k):
    #Construct the frequency dictinory for all unique characters
    unique=[]
    freq={}
    for i in s:
        if i not in freq.keys():
            freq[i]=s.count(i)
    #extract unique  frequicies in decencding order
    values=sorted(freq.values())
    uniqueValues=list(set(values))
    uniqueValues=sorted(uniqueValues,reverse=True)
    #identify kth largest freuency
    if(k<=len(uniqueValues)):
        kvalue=uniqueValues[k-1]
    else:
        return -1
    #Get all elemnets with kth largest frequencies
    li=[]
    for item in freq.items():
        if item[1]==kvalue:
            li.append(item[0])
    #minimun  if kth largest frquency
    return min(li)

kLargestFrequency('aabcccd',4)
# Out:
# -1

# %%
file='DataFiles/data.txt'

# %%
with open (file,'r') as f:
    t=int(input())
    for i in range (t):
        s=input()
        k=int(input())
        print(kLargestFrequency(s,k))
# Out:
# 2
# f
# 3
# -1
# g
# 2
# -1

# %%
#second Largest
def secondLargest(li):
    #convert the list into a unique list
    #O(n)
    unique=[]
    for n in li:
        if n not in unique:
            unique.append(n)
    unique=sorted(unique,reverse=True)
    return unique[1]

# %%
secondLargest([1,2,3,4,5,6,7,8,9,0])
# Out:
# 8

# %%
#fifth least from a given lsit
def fifthleast(li):
    unique=[]
    for i in li:
        if i not in unique:
            unique.append(i)
    unique=sorted(unique,reverse=True)
    return unique[len(unique)-5]

fifthleast([1,2,3,4,5,6,7,8,9])
# Out:
# 1

# %%
def kthleast(li,k):
    unique=[]
    for i in li:
        if i not in unique:
            unique.append(i)
    #sort the list in accending order
    unique=sorted(unique)
    #check if the length of unique list is greater than k
    if(len(unique)>=k):
        return unique[k-1]
    else:
        return -1


kthleast([112,2324,1242,353,34457,35346,4,2342365,345],10)
# Out:
# -1

# %%
def kthgreatest(li,k):
    unique=[]
    for i in li:
        if i not in unique:
            unique.append(i)
    unique=sorted(unique,reverse=True)
    #sort the list in decending order
    print(unique)
    if(len(unique)>=k):
        return unique[k-1]
    else:
        return -1


kthgreatest([112,2324,1242,353,34457,35346,4,2342365,345],4)
# Out:
# [2342365, 35346, 34457, 2324, 1242, 353, 345, 112, 4]
# 2324

# %%
#function to identifiy event with highest frquencyElement in a list
#how many elements have the highest frquency 
#highest frequency of follwing elements([1,2,3,4,5,7,3,45,2,1])
def highestFrequencyElement(li):
    unique=[]
    for i in li:
        if i  not in unique:
            unique.append(i)
    print(unique)
    frequency=[]
    for i in li:
        if i in unique:
            frequency.append(li.count(i))
    print(frequency)



li=[1,2,1,11,2,2,3,4,23,2,3,2,2,3,5,4,4,33,4,7,7,6,7]
highestFrequencyElement(li)
# Out:
# [1, 2, 11, 3, 4, 23, 5, 33, 7, 6]
# [2, 6, 2, 1, 6, 6, 3, 4, 1, 6, 3, 6, 6, 3, 1, 4, 4, 1, 4, 3, 3, 1, 3]

# %%
def highestFrequencyElement1(li):
    unique={}
    for i in li:
        if i not in unique:
            unique[i]=li.count(i)
    print(unique)
    s=[]
    s=sorted(unique.values(),reverse=True)
    print(s)
    
    
dam=[1,2,22,1,3,4,5,1,3,4,6,4,3,32,1,5,67,7]

highestFrequencyElement1(dam)
# Out:
# {1: 4, 2: 1, 22: 1, 3: 3, 4: 3, 5: 2, 6: 1, 32: 1, 67: 1, 7: 1}
# [4, 3, 3, 2, 1, 1, 1, 1, 1, 1]

# %%
def HighestFrequencyElement(li):
    unique={}
    for n in li:
        if n in unique:
            unique[n]+=1
        else:
            unique[n]=1
#Getting all frquencies into a list
    print(unique)
    freq=unique.values()
    maxfreq=max(freq)
    maxfreqkeys=[]
#identify smallest number with maximum frequency
#Extarct all keys with maximum frequency in a list
    for item in unique.items():
        #item-->(key,value)
        #item[1]
        if item[1]==maxfreq:
            maxfreqkeys.append(item[0])
#select minimum from keys with maximum frquency
    return min(maxfreqkeys) #minfreqE[k-1]
    
HighestFrequencyElement(dam)
# Out:
# {1: 4, 2: 1, 22: 1, 3: 3, 4: 3, 5: 2, 6: 1, 32: 1, 67: 1, 7: 1}
# 67

# %%
#Function to identify second highest frequency element.
#if there are many such elements ,return the second highest 
#[1,2,3,2,1,4,4,9]
def SecondFrequencyElement(li):
    unique={}
    for n in li:
        if n in unique:
            unique[n]+=1
        else:
            unique[n]=1
#Getting all frquencies into a list
   # print(unique)
    freq=unique.values()
    uniqfreq=[]
    for i in freq:
        if i not in uniqfreq:
            uniqfreq.append(i)
    uniqfreq=sorted(uniqfreq,reverse=True)
    maxfreq=uniqfreq[1]
    maxfreqkeys=[]
#identify smallest number with maximum frequency
#Extarct all keys with maximum frequency in a list
    for item in unique.items():
        #item-->(key,value)
        #item[1]
        if item[1]==maxfreq:
            maxfreqkeys.append(item[0])
           # print(maxfreqkeys)
#select minimum from keys with maximum frquency
    return min(maxfreqkeys) #minfreqE[k-1]'''
da=[1,2,3,2,1,4,4,9]
SecondFrequencyElement(da)
# Out:
# {1: 2, 2: 2, 3: 1, 4: 2, 9: 1}
# [3]
# [3, 9]
# 3

# %%
#function to identify kth

def kthhighFrequencyElement(li,k):
    unique={}
    for n in li:
        if n in unique:
            unique[n]+=1
        else:
            unique[n]=1
#Getting all frquencies into a list
    #print(unique)
    freq=unique.values()
    uniqfreq=[]
    for i in freq:
        if i not in uniqfreq:
            uniqfreq.append(i)
    uniqfreq=sorted(uniqfreq,reverse=True)
    #print(uniqfreq)
    maxfreq=uniqfreq[k-1]
    maxfreqkeys=[]
#identify smallest number with maximum frequency
#Extarct all keys with maximum frequency in a list
    for item in unique.items():
        #item-->(key,value)
        #item[1]
        if item[1]==maxfreq:
            maxfreqkeys.append(item[0])
   # print(maxfreqkeys)
#select minimum from keys with maximum frquency
    return min(maxfreqkeys) #minfreqE[k-1]'''
da=[9,8,7,6,5,2,3,4,9,7,7,7,6,7,6]
kthhighFrequencyElement(da,4)
# Out:
# 2

# %%
s=input()
k=int(input())
li=[]
for i in s:
    li.append(i)
kthhighFrequencyElement(li,k)
# Out:
# ... 25 ...
# 10
# {'r': 6939, 't': 6741, 'k': 6760, 'p': 6988, 'e': 6855, 'm': 7008, 'n': 7051, 's': 6810, 'a': 6903, 'w': 7116, 'h': 6882, 'g': 6972, 'b': 6870, 'u': 6900, 'v': 6916, 'i': 7015, 'l': 6982, 'c': 6893, 'x': 6855, 'q': 6980, 'o': 7018, 'j': 6838, 'd': 6992, 'z': 6808, 'y': 6964, 'f': 7161, ' ': 2, '2': 1, '5': 1}
# [7161, 7116, 7051, 7018, 7015, 7008, 6992, 6988, 6982, 6980, 6972, 6964, 6939, 6916, 6903, 6900, 6893, 6882, 6870, 6855, 6838, 6810, 6808, 6760, 6741, 2, 1]
# ['q']
# 'q'

# %%
s='shiva'
li=[]
for i in s:
    li.append(i)
li
# Out:
# ['s', 'h', 'i', 'v', 'a']

# %%
filename='DataFiles/k-largest-frequency-input.txt'
def mydata(filename):
    li=[]
    with open(filename,'r')as f:
        for line in f:
            li.append(line.split(','))
        return li

mydata(filename)
# Out:
# [['10\n'],
#  ['...\n'],
#  ['25\n'],
#  ['...\n'],
#  ['8\n'],
#  ['...\n'],
#  ['12\n'],
#  ['...\n'],
#  ['11\n'],
#  ['...\n'],
#  ['20\n'],
#  ['...\n'],
#  ['12\n'],
#  ['...\n'],
#  ['3\n'],
#  ['...\n'],
#  ['6\n'],
#  ['...\n'],
#  ['26\n'],
#  ['...\n'],
#  ['26']]

# %%
li=mydata(filename)
s=li[3]
str=s[0]
li=[]
for i in str:
    li.append(i)
kthhighFrequencyElement(li,8)
# Out:
# {'b': 3795, 'u': 3883, 'e': 3821, 's': 3836, 'y': 3880, 'q': 3866, 'c': 3769, 'a': 3835, 'm': 3858, 'x': 3886, 'd': 3797, 'p': 3893, 'j': 3820, 'h': 3867, 'n': 3931, 'g': 3870, 'o': 3864, 'r': 3862, 'w': 3960, 'i': 3880, 'k': 3799, 't': 3727, 'v': 3835, 'l': 3890, 'f': 3865, 'z': 3711, '\n': 1}
# [3960, 3931, 3893, 3890, 3886, 3883, 3880, 3870, 3867, 3866, 3865, 3864, 3862, 3858, 3836, 3835, 3821, 3820, 3799, 3797, 3795, 3769, 3727, 3711, 1]
# ['g']
# 'g'

# %%
with open(filename)as f:
    t=int(f.readline())
    for i in range(t):
        s=f.readline()[:-1]
        k=int(f.readline())
        print(kthhighFrequencyElement(s,k))
# Out:
# s
# g
# h
# e
# w
# r
# n
# k
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-29bb3e591171> in <module>
#       4         s=f.readline()[:-1]
#       5         k=int(f.readline())
# ----> 6         print(kthhighFrequencyElement(s,k))
#       7
#       8
#
# <ipython-input-64-97b83c7cbf1c> in kthhighFrequencyElement(li, k)
#      17     uniqfreq=sorted(uniqfreq,reverse=True)
#      18     #print(uniqfreq)
# ---> 19     maxfreq=uniqfreq[k-1]
#      20     maxfreqkeys=[]
#      21 #identify smallest number with maximum frequency
#
# IndexError: list index out of range

# %%
l=[1,2,3]
l[:-1]
# Out:
# [1, 2]
